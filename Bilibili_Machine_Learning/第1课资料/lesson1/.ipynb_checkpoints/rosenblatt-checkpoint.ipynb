266383352911, 0.3245982492816436, 0.3968639889376951, 0.35229955350974773, 0.34186695462062877, 0.4131283437601839, 0.34872794297299825, 0.44992977276668045, 0.42078459328177376, 0.44051840796989056, 0.4837840154395159, 0.4560645375289544, 0.4683365358256564, 0.5403554622597498, 0.5277007643560186, 0.516302782753163, 0.5328712812996156, 0.5376061098502606, 0.6178902625058998, 0.5725741266011383, 0.6211800083125855, 0.7060195369032212, 0.6309332895817136, 0.6289732134096027, 0.7425027076646814, 0.7558528723671107, 0.7712788286704898, 0.7334887754839038, 0.7597859027437142, 0.7130711681665178, 0.7450652416742852, 0.7956459355774893, 0.8619617237735285, 0.8621723267867525, 0.8313701288140277, 0.8487019580319561, 0.9112160852148651, 0.9025206609126692, 0.9939138366991417, 1.011090719491273, 0.9408017181050062, 1.0118811017291018, 1.0285430428407956, 1.056560394226159, 1.0441069913544971, 1.0715140654766313, 0.9964949315680892, 1.0108365760470406, 1.0284929731285457, 1.0541603000392186, 1.0610177000902534, 1.0563286612937721, 1.0501527534173702, 1.0912428934337974, 1.1427312999255452, 1.0796733753497516, 1.1200828217011742, 1.1019438702294595, 1.1312061139403415, 1.116025509304048, 1.1484453479851262, 1.174767838230347, 1.1979656784887436, 1.1647549205769006, 1.1809955680666806, 1.2486196057757697, 1.216097440934584, 1.2607890179700454, 1.2173541477066248]

# %%
# configure figure settings
plt.title("Size-Toxicity function", fontsize=12)
plt.xlabel("Bean size")
plt.ylabel("Toxicity")

plt.scatter(xs,ys)
plt.show()

# %%
# set function y = 0.5x (initialise the factor as 0.5)
w = 0.5

# %%
'''
# a single update of w
x = xs[0]
y = ys[0]
y_pre = w * x
err = y - y_pre
alpha = 0.05    # adjusting factor
w = w + alpha * err * x
plt.show()
'''
# Out:
# '\n# a single adjustment of w\nx = xs[0]\ny = ys[0]\ny_pre = w * x\nerr = y - y_pre\nalpha = 0.05    # adjusting factor\nw = w + alpha * err * x\nplt.show()\n'

# %%
# a single loop adjustment of w, not good enough
alpha = 0.05  # adjusting factor
for i in range(100):
    x = xs[i]
    y = ys[i]
    y_pre = w * x
    err = y - y_pre
    w = w + alpha * err * xs    # alpha -> adjusting step   err -> error between prediction and training value   xs -> current x value (used to ensure the adjustment is in correct direction)

y_pre = w * xs
plt.scatter(xs,ys)
plt.plot(xs, y_pre)
plt.show()

# %%
# repeat w adjusting for 100 times, good enough
alpha = 0.05  # adjusting factor
for m in range(100):
    for i in range(100):
        x = xs[i]
        y = ys[i]
        y_pre = w * x
        err = y - y_pre
        w = w + alpha * err * x

y_pre = w * xs
plt.scatter(xs,ys)
plt.plot(xs, y_pre)
plt.show()
